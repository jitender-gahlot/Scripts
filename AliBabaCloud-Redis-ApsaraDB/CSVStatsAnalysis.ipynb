# %%
import pandas as pd

# %%
pd.read_csv('/Users/5nip3r/Development/AliBabaCloud/db_1-r-6gjrc9vf30rgi6bb4apd.redis.ap-south-1.rds.aliyuncs.com.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-1be5f06135f8> in <module>
# ----> 1 pd.read_csv('/Users/5nip3r/Development/AliBabaCloud/db_1-r-6gjrc9vf30rgi6bb4apd.redis.ap-south-1.rds.aliyuncs.com.csv')
#
# ...

# %%
pd.read_csv('/Users/5nip3r/Development/AliBabaCloud/db1_r-6gjrc9vf30rgi6bb4apd.redis.ap-south-1.rds.aliyuncs.com.csv')
# Out:
#       command   operations  usec_per_op   max_memory  used_memory  \
# 0         get  12781278260         0.55  17179869184    637480424
# 1         set   3195665413         0.91  17179869184    637480424
# 2   pacluster      2394344         1.29  17179869184    637480424
# 3   adminauth      2067358         2.69  17179869184    637480424
# 4    replconf       797893         1.20  17179869184    637480424
# 5        dump       734606         2.19  17179869184    637480424
# 6         ttl       734606         0.20  17179869184    637480424
# 7        info       339110        58.81  17179869184    637480424
# 8        role       299290         7.93  17179869184    637480424
# 9      config       229264        65.65  17179869184    637480424
# 10       scan        71137        13.64  17179869184    637480424
# 11     select        19753         0.17  17179869184    637480424
# 12       type         5053         0.54  17179869184    637480424
# ...
